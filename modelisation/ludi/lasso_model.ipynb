# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler, MultiLabelBinarizer, FunctionTransformer
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error
from sklearn.model_selection import GridSearchCV, ParameterGrid
from sklearn.preprocessing import PolynomialFeatures

# %%
df = pd.read_parquet("allocine_spider_clean.parquet")
df.head(5)
# Out:
#                                               actors  critics_score  \
# 0    [George Clooney, Julia Roberts, Jack O'Connell]            3.5
# 1        [Kad Merad, Géraldine Pailhas, Lola Creton]            2.7
# 2           [Nicolas Cage, Kev Adams, Ryan Reynolds]            3.8
# 3     [Dylan O'Brien, Michael Keaton, Taylor Kitsch]            2.3
# 4  [Virginie Efira, Anaïs Demoustier, Laurent Sto...            3.5
#
#         date            director                          editor  \
# 0 2016-05-12        Jodie Foster  Sony Pictures Releasing France
# 1 2015-01-21  Christophe Lamotte                      Rezo Films
# 2 2013-04-10       Chris Sanders    Twentieth Century Fox France
# 3 2017-09-20      Michael Cuesta         Metropolitan FilmExport
# 4 2015-04-22     Emmanuel Mouret           Pyramide Distribution
#
#                                      genre     langage  length nationality  \
# 0                               [Thriller]   [Anglais]    99.0    [U.S.A.]
# 1                        [Drame, Thriller]  [Français]   100.0    [France]
# 2  [Aventure, Animation, Comédie, Famille]   [Anglais]    98.0    [U.S.A.]
# 3                       [Action, Thriller]   [Anglais]   112.0    [U.S.A.]
# 4                       [Comédie, Romance]  [Français]   100.0    [France]
#
#    viewers_score  french_first_week_boxoffice french_visa              title  \
# 0            3.6                     305385.0      144018      Money Monster
# 1            2.3                      29265.0      117439  Disparue en hiver
# 2            3.9                     501465.0      135882         Les Croods
# 3            3.2                     104402.0      147308  American Assassin
# 4            2.7                      64046.0      138835            Caprice
#
#      vo_title                                                url
# 0        None  /video/player_gen_cmedia=19561526&cfilm=214139...
# 1        None   /article/fichearticle_gen_carticle=18639324.html
# 2  The Croods  /video/player_gen_cmedia=19410286&cfilm=146916...
# 3        None  /video/player_gen_cmedia=19569927&cfilm=194970...
# 4        None             /diaporamas/cinema/diaporama-18643599/

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, test_size=0.1, random_state=42)

# %%
df.isnull().sum()
# Out:
# actors                          151
# critics_score                    22
# date                              0
# director                         15
# editor                            0
# genre                             0
# langage                           0
# length                           10
# nationality                       6
# viewers_score                   482
# french_first_week_boxoffice       0
# french_visa                       0
# title                             0
# vo_title                       4770
# url                               0
# dtype: int64

# %%
features_of_interest = [
    'actors',
    'date',
    'director',
    'editor',
    'genre',
    'langage',
    'length',
    'nationality'
]

info_film = ['french_visa', 'title', 'vo_title', 'url']

numerical_features = ['length']
date_feature = ['date']
categorical_features = ['director', 'editor']
list_categorical_features = ['actors', 'genre', 'langage', 'nationality']


list_categorical_features = ['actors', 'genre', 'langage', 'nationality']
for col in list_categorical_features:
    df[col] = df[col].mask(df[col].isna(), ['no value'])

target = 'french_first_week_boxoffice'

X, y = (
    df[features_of_interest],
    df[target]
)
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, test_size=0.1, random_state=42)

# %%
class MultiLabelBinarizerTransformer(BaseEstimator, TransformerMixin):
    def __init__(self):
        self.mlbs = {}  # Stocke un MultiLabelBinarizer pour chaque colonne
    
    def fit(self, X, y=None):
        for col in X.columns:
            self.mlbs[col] = MultiLabelBinarizer()
            self.mlbs[col].fit(X[col])
        return self
    
    def transform(self, X):
        transformed_list = []
        for col in X.columns:
            transformed = self.mlbs[col].transform(X[col])
            new_columns = [f"{col}_{label}" for label in self.mlbs[col].classes_]
            transformed_list.append(pd.DataFrame(transformed, columns=new_columns, index=X.index))
        
        return pd.concat(transformed_list, axis=1)
    
    def get_feature_names_out(self, input_features=None):
        # Collecter tous les noms de colonnes de sortie
        feature_names = []
        for col in self.mlbs.keys():
            feature_names.extend([f"{col}_{label}" for label in self.mlbs[col].classes_])
        return np.array(feature_names)

numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')), # Bourin... à changer mais j'ai même pas vérifier s'il manquait des données...
    ('scaler', StandardScaler())
])

class CustomDateTransformer(BaseEstimator, TransformerMixin):
    def __init__(self):
        self.feature_names_out = ['year', 'month', 'day', 'dayofweek']
        
    def fit(self, X, y=None):
        return self
        
    def transform(self, X):
        result = pd.DataFrame({
            'year': X['date'].dt.year,
            'month': X['date'].dt.month,
            'day': X['date'].dt.day,
            'dayofweek': X['date'].dt.dayofweek
        })
        return result
        
    def get_feature_names_out(self, input_features=None):
        return np.array(self.feature_names_out)

date_transformer = Pipeline(steps=[
    ('date_features', CustomDateTransformer())
])

# Toujours bourin :p
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

list_categorical_transformer = Pipeline(steps=[
    ('multi_label', MultiLabelBinarizerTransformer())
])

# Création du préprocesseur (sans les colonnes déjà transformées)
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_features),
        ('date', date_transformer, date_feature),
        ('cat', categorical_transformer, categorical_features),
        ('list', list_categorical_transformer, list_categorical_features)
    ],
    remainder='passthrough'
)

# %%
linear_regression_model = Pipeline([
    ('preprocessor', preprocessor),  
    ('linearregressoin', LinearRegression())
])

linear_regression_model.fit(X_train,y_train)
y_pred = linear_regression_model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"MAE: {mae}")
print(f"MAPE: {mape} %")
print(f"RMSE: {rmse}")
print(f"R²: {r2}")
# Out:
# MAE: 563175.7918972133
# MAPE: 461.3643001980008 %
# RMSE: 945694.8043167448
# R²: 0.05787069546565793
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) [' .jU.', ' Champagna', ' Christophe', ' Marie-Mai', ' Océane', ' RZA', ' Sunil', ' Tabu', ' Tal', 'Aamito Lagum', 'Aaron Abrams', 'Abbi Jacobson', 'Abhay Verma', 'Abolfazl Kahani', 'Achille Reggiani', 'Adrian Purcărescu', 'Adrien Dussaiwoir', 'Agathe Talrich', 'Agnès Delachair', 'Aitziber Garmendia', 'Akina Minami', 'Alain Cavalier', 'Alban Ukaj', 'Albert Brooks', 'Aleksandr Chutko', 'Aleksandra Justa', 'Alessandra Mastronardi', 'Alessandro Nivola', 'Alex Cox', 'Alex Lawther', 'Alex Ross Perry', 'Alex Van Warmerdam', 'Alexander Siddig', 'Alexandre Laigner', 'Alexis Neises', 'Alice Daubelcour', 'Alice Pehlivanyan', 'Alik Karaev', 'Alix Poisson', 'Amalia Salas', 'Amanda Crew', 'America Olivo', 'Ami Smolartchik', 'Ammy Virk', 'Amrit Maghera', 'Amy Deasismont', 'Amélie Abrieu', 'Ana Cabral', 'Ana Ivanova', 'Ana Sofía Durand', 'Andrea Alzuri', 'Andrey Gusev', 'Andrés Gertrudix', 'Anemone Valcke', 'Angelo Mutti Spinetta', 'Anna Gaylor', 'Anne Heche', 'Anne Kessler', 'Anne Steffens', 'Anne-Christine Caro', 'Anne-Jacqueline Bousch', 'Annika Hallin', 'Anthony B. Jenkins', 'Anthony Pho', 'Antoine Pirotte', 'Antoine de Maximy', 'Antonia Bill', 'Antonia Giesen', 'Antonio Altamirano', 'Antonio Centeno', 'Antony Starr', 'Anu Emmanuel', 'Ariel Mateluna', 'Armelle Deutsch', 'Arta Dobroshi', 'Arántzazu Ruiz', 'Asher Lax', 'Ashley Hinshaw', 'Assi Levy', 'Astrid Lindgren', 'Athena Strates', 'Atle Antonsen', 'Atsuko Miyake', 'Audrey Beaulieu', 'Axel Philippon', 'Axelle Laffont', 'Baptiste Lalieu', 'Barbara Beretta', 'Barbara Sarafian', 'Barkhad Abdi', 'Bastien Tosetti', 'Batyste Fleurial', 'Bea Palya', 'Ben Temple', 'Bengt Nilsson', 'Benhame Tashakor', 'Benjamin Robert', 'Benjamin Siksou', 'Benoît Chauvin', 'Benoît Delépine', 'Bernard Bureau', 'Bertrand Bonello', 'Bertrand de Roffignac', 'Blake Jenner', 'Bob Byington', 'Boguslaw Linda', 'Bojena Horackova', 'Bonnie Aarons', 'Brahim Tekfa', 'Brigitte Fontaine', 'Bronislawa Zamachowska', 'Bruno Fernandes (II)', 'Bruno Lopez', 'Camila Pitanga', 'Camille Bardery', 'Carlen Altman', 'Carlo Buccirosso', 'Carlo Cecchi', 'Carlos Vallarino', 'Carole Eugenie', 'Carole Lesguillon', 'Carole Lo', 'Carolina Amaral', 'Caroline Vigneaux', 'Cary Elwes', 'Cary-Hiroyuki Tagawa', 'Cas Anvar', 'Catherine Marchal', 'Cathy Boquet', 'Cathy Nouchi', 'Cem Göktas', 'Cendrine Genty', 'Cezar Antal', 'Charles Crombez', 'Charles Mérienne', 'Charles-Aubey Houde', 'Charlie Tahan', 'Chen Bor Jeng', 'Chencho Dorji', 'Chiara Capitani', 'Chiara Caselli', 'Ching Wan Lau', 'Chris Morley', 'Christian Patrick', 'Christine Kain', 'Christoph Bach', 'Christophe Hamon', 'Christophe Lemoine', 'Christophe Sauvion', 'Christopher Convery', 'Cindy Dumont', 'Cindy Rodrigues', 'Claire Cahen', 'Claire Pommet', 'Claire Suchet', 'Clare Agiue', 'Claude Mathieu', 'Claude Morel', 'Claude Perron', 'Claudia Bacos', 'Cleopatra Coleman', 'Clotilde Mollet', 'Clément Olivieri', 'Colin Salmon', 'Colin Woodell', 'Coline Chantrel', 'Constantin Leu', 'Consuelo Carreño', 'Corneliu Cozmei', 'Cosmo Jarvis', 'Costas Mandylor', 'Cristian Borges', 'Cristiana Branquinho', 'Cynthia Nixon', 'Cécile Fisera', 'Dacre Montgomery', 'Dady Brieva', 'Dae Al Hilali', 'Damien Roussineau', 'Daniel Hendler', 'Danny Kwok-Kwan Chan', 'David Belle', 'David Elmaleh', 'David Holt', 'David Illescas', 'David Merabet', 'David Rauchenberger', 'David Saracino', 'David Winters', 'Debra Messing', 'Denise Ho', 'Deniz Orta', 'Deragh Campbell', 'Devon Bostick', 'Diana Avrămuţ', 'Dieter Hallervorden', 'Dimitri Sani', 'Diomaye A. Ngom', 'Diong-Keba Tacu', 'Djemel Barek', 'Dmitri Groshev', 'Do Thi Hai Yen', 'Don Gallagher', 'Dora Freind', 'Dorian Le Clech', 'Dorothée Dentel', 'Dounia Sichov', 'Dustin Guy Defa', 'Dustin Ray', 'Ece Bağcı', 'Elena Andrada', 'Elena Cotta', 'Elisabeth Locas', 'Elizabeth McGovern', 'Ellen Jelinek', 'Elmo N ...
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Mauritanie', 'Nigéria', 'Paraguay'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(

# %%
list_categorical_features = ['genre', 'langage', 'nationality', 'actors']
for col in list_categorical_features:
    df[col] = df[col].mask(df[col].isna(), ['no value'])
    
df['french_prod']= df['nationality'].apply(lambda x: 1 if "France" in x else 0)
df['usa_prod']= df['nationality'].apply(lambda x: 1 if "U.S.A." in x else 0)


list_categorical_features = ['genre', 'langage']
features_of_interest = [
    'french_prod',
    'date',
    'director',
    'editor',
    'genre',
    'langage',
    'length',
    'usa_prod',
]

info_film = ['french_visa', 'title', 'vo_title', 'url']

numerical_features = ['length']
date_feature = ['date']
categorical_features = ['director', 'editor']
list_categorical_features = ['genre', 'langage']


target = 'french_first_week_boxoffice'

X, y = (
    df[features_of_interest],
    df[target]
)
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, test_size=0.1, random_state=42)

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_features),
        ('date', date_transformer, date_feature),
        ('cat', categorical_transformer, categorical_features),
        ('list', list_categorical_transformer, list_categorical_features)
    ],
    remainder='passthrough'
)

linear_regression_model = Pipeline([
    ('preprocessor', preprocessor),  
    ('linearregressoin', LinearRegression())
])

linear_regression_model.fit(X_train,y_train)
y_pred = linear_regression_model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"MAE: {mae}")
print(f"MAPE: {mape} %")
print(f"RMSE: {rmse}")
print(f"R²: {r2}")
# Out:
# MAE: 264972.39873315766
# MAPE: 263.1591880094103 %
# RMSE: 591416.6320177614
# R²: 0.6315355659804622
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(

# %%
#Lasso

list_categorical_features = ['genre', 'langage', 'nationality', 'actors']
for col in list_categorical_features:
    df[col] = df[col].mask(df[col].isna(), ['no value'])
    
df['french_prod']= df['nationality'].apply(lambda x: 1 if "France" in x else 0)
df['usa_prod']= df['nationality'].apply(lambda x: 1 if "U.S.A." in x else 0)


list_categorical_features = ['genre', 'langage']
features_of_interest = [
    'french_prod',
    'date',
    'director',
    'editor',
    'genre',
    'langage',
    'length',
    'usa_prod',
]

info_film = ['french_visa', 'title', 'vo_title', 'url']

numerical_features = ['length']
date_feature = ['date']
categorical_features = ['director', 'editor']
list_categorical_features = ['genre', 'langage']


target = 'french_first_week_boxoffice'

X, y = (
    df[features_of_interest],
    df[target]
)
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, test_size=0.1, random_state=42)

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_features),
        ('date', date_transformer, date_feature),
        ('cat', categorical_transformer, categorical_features),
        ('list', list_categorical_transformer, list_categorical_features)
    ],
    remainder='passthrough'
)

lasso_model = Pipeline([
    ('preprocessor', preprocessor),  
    ('lassomodel', Lasso(alpha=10, random_state=42))
])

lasso_model.fit(X_train,y_train)
y_pred = lasso_model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"MAE: {mae}")
print(f"MAPE: {mape} %")
print(f"RMSE: {rmse}")
print(f"R²: {r2}")
# Out:
# MAE: 174586.29661733532
# MAPE: 116.66422190675844 %
# RMSE: 540647.6839939922
# R²: 0.6920804946973367
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(

# %%
# Ridge

list_categorical_features = ['genre', 'langage', 'nationality', 'actors']
for col in list_categorical_features:
    df[col] = df[col].mask(df[col].isna(), ['no value'])
    
df['french_prod']= df['nationality'].apply(lambda x: 1 if "France" in x else 0)
df['usa_prod']= df['nationality'].apply(lambda x: 1 if "U.S.A." in x else 0)


list_categorical_features = ['genre', 'langage']
features_of_interest = [
    'french_prod',
    'date',
    'director',
    'editor',
    'genre',
    'langage',
    'length',
    'usa_prod',
]

info_film = ['french_visa', 'title', 'vo_title', 'url']

numerical_features = ['length']
date_feature = ['date']
categorical_features = ['director', 'editor']
list_categorical_features = ['genre', 'langage']


target = 'french_first_week_boxoffice'

X, y = (
    df[features_of_interest],
    df[target]
)
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, test_size=0.1, random_state=42)

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_features),
        ('date', date_transformer, date_feature),
        ('cat', categorical_transformer, categorical_features),
        ('list', list_categorical_transformer, list_categorical_features)
    ],
    remainder='passthrough'
)

ridge_model = Pipeline([
    ('preprocessor', preprocessor),  
    ('rigdemodel', Ridge())
])

ridge_model.fit(X_train,y_train)
y_pred = ridge_model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"MAE: {mae}")
print(f"MAPE: {mape} %")
print(f"RMSE: {rmse}")
print(f"R²: {r2}")
# Out:
# MAE: 173849.23317083772
# MAPE: 111.79013991793681 %
# RMSE: 698292.670654377
# R²: 0.48633086151555704
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(

# %%
# Elasticnet

list_categorical_features = ['genre', 'langage', 'nationality', 'actors']
for col in list_categorical_features:
    df[col] = df[col].mask(df[col].isna(), ['no value'])
    
df['french_prod']= df['nationality'].apply(lambda x: 1 if "France" in x else 0)
df['usa_prod']= df['nationality'].apply(lambda x: 1 if "U.S.A." in x else 0)


list_categorical_features = ['genre', 'langage']
features_of_interest = [
    'french_prod',
    'date',
    'director',
    'editor',
    'genre',
    'langage',
    'length',
    'usa_prod',
]

info_film = ['french_visa', 'title', 'vo_title', 'url']

numerical_features = ['length']
date_feature = ['date']
categorical_features = ['director', 'editor']
list_categorical_features = ['genre', 'langage']


target = 'french_first_week_boxoffice'

X, y = (
    df[features_of_interest],
    df[target]
)
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, test_size=0.1, random_state=42)

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_features),
        ('date', date_transformer, date_feature),
        ('cat', categorical_transformer, categorical_features),
        ('list', list_categorical_transformer, list_categorical_features)
    ],
    remainder='passthrough'
)

elastic_model = Pipeline([
    ('preprocessor', preprocessor),  
    ('elasticnet', ElasticNet(alpha=1))
])

elastic_model.fit(X_train,y_train)
y_pred = elastic_model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"MAE: {mae}")
print(f"MAPE: {mape} %")
print(f"RMSE: {rmse}")
print(f"R²: {r2}")
# Out:
# MAE: 186919.11723180313
# MAPE: 127.04269509226741 %
# RMSE: 956465.8093908563
# R²: 0.036287689940789125
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(

# %%
# Grille des valeurs de alpha à tester
param_grid = {
    'lassomodel__alpha': np.logspace(-3, 2, 20)  # de 0.001 à 100
}

# Pipeline complet (repris de ton code)
lasso_model = Pipeline([
    ('preprocessor', preprocessor),  
    ('lassomodel', Lasso(random_state=42))
])

# GridSearch
grid_search = GridSearchCV(
    lasso_model,
    param_grid,
    cv=5,
    scoring='neg_mean_absolute_error',
    n_jobs=-1,
    verbose=1
)

# Fit
grid_search.fit(X_train, y_train)

# Meilleur modèle
best_lasso = grid_search.best_estimator_
print(f"Meilleur alpha : {grid_search.best_params_['lassomodel__alpha']}")
print(f"Score MAE (cross-val) : {-grid_search.best_score_}")

# Évaluation sur le test set
y_pred = best_lasso.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"\n--- Évaluation finale sur le test set ---")
print(f"MAE: {mae}")
print(f"MAPE: {mape * 100:.2f} %")
print(f"RMSE: {rmse}") 
print(f"R²: {r2}")
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 648563170645189.8, tolerance: 383167000903.66693
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Spectacle'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Araméen', 'Punjabi'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 616612305602420.1, tolerance: 383167000903.66693
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Spectacle'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Araméen', 'Punjabi'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 669698487175682.6, tolerance: 383167000903.66693
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Spectacle'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Araméen', 'Punjabi'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 231751110879276.47, tolerance: 300925922322.9
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Concert'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['BAMBARA', 'Galicien', 'Malgache'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 235313266237250.06, tolerance: 300925922322.9
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Concert'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['BAMBARA', 'Galicien', 'Malgache'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 231659832646893.34, tolerance: 300925922322.9
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Concert'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 549095083960888.7, tolerance: 363691598239.659
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['BAMBARA', 'Galicien', 'Malgache'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Drama'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['', 'Inuktitut', 'Klingon', 'Pashto'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 456265650303149.75, tolerance: 347155691626.3761
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Amharique', 'Mongol'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 563641240100597.8, tolerance: 363691598239.659
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Drama'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['', 'Inuktitut', 'Klingon', 'Pashto'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 435843848111045.2, tolerance: 347155691626.3761
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Amharique', 'Mongol'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 415883006547414.06, tolerance: 347155691626.3761
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Amharique', 'Mongol'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 562588396119583.94, tolerance: 363691598239.659
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Drama'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['', 'Inuktitut', 'Klingon', 'Pashto'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 229366390280829.03, tolerance: 300925922322.9
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Concert'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['BAMBARA', 'Galicien', 'Malgache'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 604934274273431.2, tolerance: 383167000903.66693
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Spectacle'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Araméen', 'Punjabi'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 219769049932288.03, tolerance: 300925922322.9
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Concert'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['BAMBARA', 'Galicien', 'Malgache'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 393895715430420.6, tolerance: 347155691626.3761
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Amharique', 'Mongol'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 175335196074511.6, tolerance: 300925922322.9
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Concert'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['BAMBARA', 'Galicien', 'Malgache'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 349396496602720.5, tolerance: 347155691626.3761
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Amharique', 'Mongol'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 288279966822213.25, tolerance: 347155691626.3761
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Amharique', 'Mongol'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 537843682562162.75, tolerance: 363691598239.659
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Drama'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['', 'Inuktitut', 'Klingon', 'Pashto'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 583019445756200.8, tolerance: 383167000903.66693
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Spectacle'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Araméen', 'Punjabi'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 553260277148639.9, tolerance: 383167000903.66693
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Spectacle'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Araméen', 'Punjabi'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 485167762768377.1, tolerance: 363691598239.659
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Drama'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['', 'Inuktitut', 'Klingon', 'Pashto'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 449498257532601.6, tolerance: 363691598239.659
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Drama'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['', 'Inuktitut', 'Klingon', 'Pashto'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 131851285939936.22, tolerance: 300925922322.9
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Concert'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['BAMBARA', 'Galicien', 'Malgache'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 140113511850845.38, tolerance: 300925922322.9
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 340120448018560.7, tolerance: 383167000903.66693
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Concert'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Spectacle'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['BAMBARA', 'Galicien', 'Malgache'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Araméen', 'Punjabi'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 341966640535854.1, tolerance: 347155691626.3761
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Amharique', 'Mongol'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 359198881535564.2, tolerance: 383167000903.66693
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Spectacle'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Araméen', 'Punjabi'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 469361784921608.9, tolerance: 363691598239.659
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Drama'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['', 'Inuktitut', 'Klingon', 'Pashto'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 124484385866097.03, tolerance: 300925922322.9
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Concert'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['BAMBARA', 'Galicien', 'Malgache'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 352174030863885.06, tolerance: 347155691626.3761
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Amharique', 'Mongol'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# ...
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Drama'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['', 'Inuktitut', 'Klingon', 'Pashto'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Amharique', 'Mongol'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Spectacle'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Araméen', 'Punjabi'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Concert'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['BAMBARA', 'Galicien', 'Malgache'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Drama'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['', 'Inuktitut', 'Klingon', 'Pashto'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3721275100229.5, tolerance: 383167000903.66693
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Spectacle'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Araméen', 'Punjabi'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 20 fits failed out of a total of 100.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py", line 654, in fit
#     Xt = self._fit(X, y, routed_params, raw_params=params)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py", line 588, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/joblib/memory.py", line 312, in __call__
#     return self.func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py", line 1551, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/utils/_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/compose/_column_transformer.py", line 1001, in fit_transform
#     result = self._call_func_on_transformers(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/compose/_column_transformer.py", line 910, in _call_func_on_transformers
#     return Parallel(n_jobs=self.n_jobs)(jobs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/utils/parallel.py", line 77, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/joblib/parallel.py", line 1918, in __call__
#     return output if self.return_generator else list(output)
#                                                 ^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/joblib/parallel.py", line 1847, in _get_sequential_output
#     res = func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/utils/parallel.py", line 139, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py", line 1551, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py", line 718, in fit_transform
#     Xt = self._fit(X, y, routed_params)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py", line 588, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/joblib/memory.py", line 312, in __call__
#     return self.func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py", line 1551, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/utils/_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/base.py", line 921, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/impute/_base.py", line 451, in fit
#     self.statistics_ = self._dense_fit(
#                        ^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/impute/_base.py", line 563, in _dense_fit
#     most_frequent[i] = _most_frequent(row, np.nan, 0)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/impute/_base.py", line 53, in _most_frequent
#     most_frequent_value = min(
#                           ^^^^
# TypeError: '<' not supported between instances of 'str' and 'NoneType'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan]
#   warnings.warn(
# Meilleur alpha : 0.001
# Score MAE (cross-val) : nan
#
# --- Évaluation finale sur le test set ---
# MAE: 268239.9141353349
# MAPE: 24906.97 %
# RMSE: 593319.1631020171
# R²: 0.6291611228196736
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 651826506576505.0, tolerance: 427301394348.2248
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(

# %%
# Pipeline
ridge_model = Pipeline([
    ('preprocessor', preprocessor),  
    ('ridge_model', Ridge(random_state=42))
])

# Grille de recherche (valide pour Ridge avec sparse)
param_grid = {
    'ridge_model__alpha': [1, 10, 100, 290, 500],
    'ridge_model__solver': ['lsqr', 'sparse_cg', 'sag', 'saga'],  # on retire 'svd' ici pour éviter les soucis
    'ridge_model__fit_intercept': [True, False],
}

# GridSearchCV
grid_search = GridSearchCV(
    ridge_model,
    param_grid=param_grid,
    cv=5,
    scoring='neg_mean_absolute_error',
    n_jobs=-1,
    verbose=1
)

# Fit
grid_search.fit(X_train, y_train)

# Meilleur modèle
best_ridge = grid_search.best_estimator_
best_params = grid_search.best_params_

print(f"✅ Meilleur alpha : {best_params['ridge_model__alpha']}")
print(f"✅ Meilleur solver : {best_params['ridge_model__solver']}")
print(f"✅ Meilleur fit_intercept : {best_params['ridge_model__fit_intercept']}")
print(f"Score MAE (cross-val) : {-grid_search.best_score_:.2f}")

# Évaluation sur test set
y_pred = best_ridge.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"\n--- 📊 Évaluation sur le test set ---")
print(f"MAE: {mae:.2f}")
print(f"MAPE: {mape * 100:.2f} %")
print(f"RMSE: {rmse:.2f}")
print(f"R²: {r2:.4f}")
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Concert'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['BAMBARA', 'Galicien', 'Malgache'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Amharique', 'Mongol'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Spectacle'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Drama'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Araméen', 'Punjabi'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['', 'Inuktitut', 'Klingon', 'Pashto'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Amharique', 'Mongol'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Spectacle'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Araméen', 'Punjabi'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Amharique', 'Mongol'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Concert'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['BAMBARA', 'Galicien', 'Malgache'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Drama'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['', 'Inuktitut', 'Klingon', 'Pashto'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Spectacle'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Araméen', 'Punjabi'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Drama'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['', 'Inuktitut', 'Klingon', 'Pashto'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Concert'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['BAMBARA', 'Galicien', 'Malgache'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Concert'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['BAMBARA', 'Galicien', 'Malgache'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Amharique', 'Mongol'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Spectacle'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Araméen', 'Punjabi'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Drama'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['', 'Inuktitut', 'Klingon', 'Pashto'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Concert'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['BAMBARA', 'Galicien', 'Malgache'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Amharique', 'Mongol'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Spectacle'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Araméen', 'Punjabi'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Drama'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['', 'Inuktitut', 'Klingon', 'Pashto'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Concert'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['BAMBARA', 'Galicien', 'Malgache'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Amharique', 'Mongol'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Spectacle'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Araméen', 'Punjabi'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Drama'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['', 'Inuktitut', 'Klingon', 'Pashto'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Concert'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['BAMBARA', 'Galicien', 'Malgache'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Amharique', 'Mongol'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Spectacle'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Araméen', 'Punjabi'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Drama'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['', 'Inuktitut', 'Klingon', 'Pashto'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Concert'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['BAMBARA', 'Galicien', 'Malgache'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Spectacle'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Concert'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Amharique', 'Mongol'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Araméen', 'Punjabi'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['BAMBARA', 'Galicien', 'Malgache'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Amharique', 'Mongol'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Spectacle'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Araméen', 'Punjabi'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Drama'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['', 'Inuktitut', 'Klingon', 'Pashto'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Drama'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['', 'Inuktitut', 'Klingon', 'Pashto'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Amharique', 'Mongol'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Concert'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['BAMBARA', 'Galicien', 'Malgache'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Concert'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['BAMBARA', 'Galicien', 'Malgache'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Amharique', 'Mongol'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Drama'] will be ignored
#   warnings.warn(
# ...
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Amharique', 'Mongol'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Concert'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['BAMBARA', 'Galicien', 'Malgache'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Spectacle'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Araméen', 'Punjabi'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Drama'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['', 'Inuktitut', 'Klingon', 'Pashto'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 60 fits failed out of a total of 200.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 40 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py", line 654, in fit
#     Xt = self._fit(X, y, routed_params, raw_params=params)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py", line 588, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/joblib/memory.py", line 312, in __call__
#     return self.func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py", line 1551, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/utils/_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/compose/_column_transformer.py", line 1001, in fit_transform
#     result = self._call_func_on_transformers(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/compose/_column_transformer.py", line 910, in _call_func_on_transformers
#     return Parallel(n_jobs=self.n_jobs)(jobs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/utils/parallel.py", line 77, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/joblib/parallel.py", line 1918, in __call__
#     return output if self.return_generator else list(output)
#                                                 ^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/joblib/parallel.py", line 1847, in _get_sequential_output
#     res = func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/utils/parallel.py", line 139, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py", line 1551, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py", line 718, in fit_transform
#     Xt = self._fit(X, y, routed_params)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py", line 588, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/joblib/memory.py", line 312, in __call__
#     return self.func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py", line 1551, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/utils/_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/base.py", line 921, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/impute/_base.py", line 451, in fit
#     self.statistics_ = self._dense_fit(
#                        ^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/impute/_base.py", line 563, in _dense_fit
#     most_frequent[i] = _most_frequent(row, np.nan, 0)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/impute/_base.py", line 53, in _most_frequent
#     most_frequent_value = min(
#                           ^^^^
# TypeError: '<' not supported between instances of 'str' and 'NoneType'
#
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py", line 662, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py", line 1249, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py", line 930, in fit
#     raise ValueError(
# ValueError: solver='saga' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'lsqr', 'sparse_cg', 'sag', 'lbfgs' or set `fit_intercept=False`
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan]
#   warnings.warn(
# ✅ Meilleur alpha : 1
# ✅ Meilleur solver : lsqr
# ✅ Meilleur fit_intercept : True
# Score MAE (cross-val) : nan
#
# --- 📊 Évaluation sur le test set ---
# MAE: 174012.37
# MAPE: 11031.66 %
# RMSE: 707366.62
# R²: 0.4729
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(

# %%
# Pipeline avec ElasticNet
elastic_model = Pipeline([
    ('preprocessor', preprocessor),  
    ('elasticnet', ElasticNet(random_state=42, max_iter=10000))
])

# Grille des hyperparamètres à tester
param_grid = {
    'elasticnet__alpha': [0.01, 0.1, 1, 10, 100],
    'elasticnet__l1_ratio': [0.1, 0.3, 0.5, 0.7, 0.9, 1],
    'elasticnet__fit_intercept': [True, False]
}

# GridSearch
grid_search = GridSearchCV(
    elastic_model,
    param_grid=param_grid,
    scoring='neg_mean_absolute_error',  # ou 'r2', 'neg_root_mean_squared_error' etc.
    cv=5,
    n_jobs=-1,
    verbose=1
)

# Fit du GridSearch
grid_search.fit(X_train, y_train)

# Meilleur modèle
best_elastic = grid_search.best_estimator_
best_params = grid_search.best_params_

print(f"\n✅ Meilleurs paramètres :")
print(f"Alpha : {best_params['elasticnet__alpha']}")
print(f"L1_ratio : {best_params['elasticnet__l1_ratio']}")
print(f"Fit_intercept : {best_params['elasticnet__fit_intercept']}")
print(f"Score MAE (cross-val) : {-grid_search.best_score_:.2f}")
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Concert'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['BAMBARA', 'Galicien', 'Malgache'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Spectacle'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Araméen', 'Punjabi'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Amharique', 'Mongol'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Amharique', 'Mongol'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Concert'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['BAMBARA', 'Galicien', 'Malgache'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Drama'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['', 'Inuktitut', 'Klingon', 'Pashto'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Amharique', 'Mongol'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Spectacle'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Araméen', 'Punjabi'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Concert'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['BAMBARA', 'Galicien', 'Malgache'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Drama'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['', 'Inuktitut', 'Klingon', 'Pashto'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Spectacle'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Araméen', 'Punjabi'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Drama'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['', 'Inuktitut', 'Klingon', 'Pashto'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Concert'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['BAMBARA', 'Galicien', 'Malgache'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Amharique', 'Mongol'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Spectacle'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Araméen', 'Punjabi'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Drama'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['', 'Inuktitut', 'Klingon', 'Pashto'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Concert'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['BAMBARA', 'Galicien', 'Malgache'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Concert'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['BAMBARA', 'Galicien', 'Malgache'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Amharique', 'Mongol'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Amharique', 'Mongol'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Spectacle'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Araméen', 'Punjabi'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Spectacle'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Araméen', 'Punjabi'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Drama'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['', 'Inuktitut', 'Klingon', 'Pashto'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Drama'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['', 'Inuktitut', 'Klingon', 'Pashto'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Concert'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['BAMBARA', 'Galicien', 'Malgache'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Amharique', 'Mongol'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Drama'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['', 'Inuktitut', 'Klingon', 'Pashto'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Spectacle'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Araméen', 'Punjabi'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Concert'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['BAMBARA', 'Galicien', 'Malgache'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Amharique', 'Mongol'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Spectacle'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Araméen', 'Punjabi'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Drama'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['', 'Inuktitut', 'Klingon', 'Pashto'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Concert'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['BAMBARA', 'Galicien', 'Malgache'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Drama'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['', 'Inuktitut', 'Klingon', 'Pashto'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Spectacle'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Araméen', 'Punjabi'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Amharique', 'Mongol'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Amharique', 'Mongol'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Concert'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['BAMBARA', 'Galicien', 'Malgache'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Spectacle'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Araméen', 'Punjabi'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Drama'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['', 'Inuktitut', 'Klingon', 'Pashto'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Concert'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['BAMBARA', 'Galicien', 'Malgache'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Amharique', 'Mongol'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Spectacle'] will be ignored
#   warnings.warn(
# ...
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7330501393392.25, tolerance: 383167000903.66693
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Spectacle'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Araméen', 'Punjabi'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 752295500108.25, tolerance: 347155691626.3761
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Amharique', 'Mongol'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 308433279323578.0, tolerance: 383167000903.66693
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Spectacle'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Araméen', 'Punjabi'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 400492282257217.94, tolerance: 363691598239.659
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Drama'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['', 'Inuktitut', 'Klingon', 'Pashto'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31481772668457.625, tolerance: 363691598239.659
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['Drama'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['', 'Inuktitut', 'Klingon', 'Pashto'] will be ignored
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 60 fits failed out of a total of 300.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 60 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py", line 654, in fit
#     Xt = self._fit(X, y, routed_params, raw_params=params)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py", line 588, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/joblib/memory.py", line 312, in __call__
#     return self.func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py", line 1551, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/utils/_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/compose/_column_transformer.py", line 1001, in fit_transform
#     result = self._call_func_on_transformers(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/compose/_column_transformer.py", line 910, in _call_func_on_transformers
#     return Parallel(n_jobs=self.n_jobs)(jobs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/utils/parallel.py", line 77, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/joblib/parallel.py", line 1918, in __call__
#     return output if self.return_generator else list(output)
#                                                 ^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/joblib/parallel.py", line 1847, in _get_sequential_output
#     res = func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/utils/parallel.py", line 139, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py", line 1551, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py", line 718, in fit_transform
#     Xt = self._fit(X, y, routed_params)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py", line 588, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/joblib/memory.py", line 312, in __call__
#     return self.func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py", line 1551, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/utils/_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/base.py", line 921, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/impute/_base.py", line 451, in fit
#     self.statistics_ = self._dense_fit(
#                        ^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/impute/_base.py", line 563, in _dense_fit
#     most_frequent[i] = _most_frequent(row, np.nan, 0)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/impute/_base.py", line 53, in _most_frequent
#     most_frequent_value = min(
#                           ^^^^
# TypeError: '<' not supported between instances of 'str' and 'NoneType'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan]
#   warnings.warn(
# ✅ Meilleurs paramètres :
# Alpha : 0.01
# L1_ratio : 0.1
# Fit_intercept : True
# Score MAE (cross-val) : nan

# %% [markdown]
# Lasso seems to be the best model of all linear model.

# %%
#Lasso with polynomial features

list_categorical_features = ['genre', 'langage', 'nationality', 'actors']
for col in list_categorical_features:
    df[col] = df[col].mask(df[col].isna(), ['no value'])
    
df['french_prod']= df['nationality'].apply(lambda x: 1 if "France" in x else 0)
df['usa_prod']= df['nationality'].apply(lambda x: 1 if "U.S.A." in x else 0)


list_categorical_features = ['genre', 'langage']
features_of_interest = [
    'french_prod',
    'date',
    'director',
    'editor',
    'genre',
    'langage',
    'length',
    'usa_prod',
]

info_film = ['french_visa', 'title', 'vo_title', 'url']

numerical_features = ['length']
date_feature = ['date']
categorical_features = ['director', 'editor']
list_categorical_features = ['genre', 'langage']


target = 'french_first_week_boxoffice'

X, y = (
    df[features_of_interest],
    df[target]
)
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, test_size=0.1, random_state=42)

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_features),
        ('date', date_transformer, date_feature),
        ('cat', categorical_transformer, categorical_features),
        ('list', list_categorical_transformer, list_categorical_features)
    ],
    remainder='passthrough'
)
polynomial = PolynomialFeatures(degree=2)
lasso_model = Pipeline([
    ('preprocessor', preprocessor), 
    ('polynomial', polynomial) ,
    ('lassomodel', Lasso(alpha=10, random_state=42))
])

lasso_model.fit(X_train,y_train)
y_pred = lasso_model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"MAE: {mae}")
print(f"MAPE: {mape} %")
print(f"RMSE: {rmse}")
print(f"R²: {r2}")
# Out:
# MAE: 186340.39836119258
# MAPE: 125.21561102212364 %
# RMSE: 560877.185734177
# R²: 0.6686064460917378
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11439565918941.75, tolerance: 427301394348.2248
#   model = cd_fast.sparse_enet_coordinate_descent(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# /home/utilisateur/Documents/cinema/new_is_always_better/modelisation/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
