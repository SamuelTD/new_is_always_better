# %%
import pandas as pd
from azure.ai.ml import MLClient
from azure.identity import DefaultAzureCredential
import pyarrow
import numpy as np
import pyarrow as pa
import pyarrow.parquet as pq

# %%
file_name = "allo_cine"
version="10"

ml_client = MLClient(
    credential=DefaultAzureCredential(),
    subscription_id="72eb7803-e874-44cb-b6d9-33f2fa3eb88c",
    resource_group_name="vpoutotrg",
    workspace_name="mlstudio-groupe4"
)

data_asset = ml_client.data.get(file_name, version=version)
print(data_asset.path)


df = pd.read_parquet(data_asset.path)

df.head()
# Out:
# azureml://subscriptions/72eb7803-e874-44cb-b6d9-33f2fa3eb88c/resourcegroups/vpoutotrg/workspaces/mlstudio-groupe4/datastores/workspaceblobstore/paths/UI/2025-04-08_094406_UTC/allocine_spider.parquet
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Overriding of current MeterProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Overriding of current MeterProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
#                                             actors critics_score        date  \
# 0      George Clooney|Julia Roberts|Jack O'Connell           3.5  2016-05-12
# 1          Kad Merad|Géraldine Pailhas|Lola Creton           2.7  2015-01-21
# 2             Nicolas Cage|Kev Adams|Ryan Reynolds           3.8  2013-04-10
# 3       Dylan O'Brien|Michael Keaton|Taylor Kitsch           2.3  2017-09-20
# 4  Virginie Efira|Anaïs Demoustier|Laurent Stocker           3.5  2015-04-22
#
#              director                          editor  french_boxoffice  \
# 0        Jodie Foster  Sony Pictures Releasing France            847743
# 1  Christophe Lamotte                      Rezo Films             44310
# 2       Chris Sanders    Twentieth Century Fox France           2350349
# 3      Michael Cuesta         Metropolitan FilmExport            260465
# 4     Emmanuel Mouret           Pyramide Distribution            125641
#
#    french_first_week_boxoffice french_visa  \
# 0                     305385.0      144018
# 1                      29265.0      117439
# 2                     501465.0      135882
# 3                     104402.0      147308
# 4                      64046.0      138835
#
#                                 genre   langage length nationality  \
# 0                            Thriller   Anglais     99      U.S.A.
# 1                      Drame|Thriller  Français    100      France
# 2  Aventure|Animation|Comédie|Famille   Anglais     98      U.S.A.
# 3                     Action|Thriller   Anglais    112      U.S.A.
# 4                     Comédie|Romance  Français    100      France
#
#                title                                                url  \
# 0      Money Monster  /video/player_gen_cmedia=19561526&cfilm=214139...
# 1  Disparue en hiver   /article/fichearticle_gen_carticle=18639324.html
# 2         Les Croods  /video/player_gen_cmedia=19410286&cfilm=146916...
# 3  American Assassin  /video/player_gen_cmedia=19569927&cfilm=194970...
# 4            Caprice             /diaporamas/cinema/diaporama-18643599/
#
#   viewers_score    vo_title
# 0           3.6        None
# 1           2.3        None
# 2           3.9  The Croods
# 3           3.2        None
# 4           2.7        None

# %%
df_test=df[['actors', 'critics_score', 'date']]

# %%
df_test
# Out:
#                                                  actors critics_score  \
# 0           George Clooney|Julia Roberts|Jack O'Connell           3.5
# 1               Kad Merad|Géraldine Pailhas|Lola Creton           2.7
# 2                  Nicolas Cage|Kev Adams|Ryan Reynolds           3.8
# 3            Dylan O'Brien|Michael Keaton|Taylor Kitsch           2.3
# 4       Virginie Efira|Anaïs Demoustier|Laurent Stocker           3.5
# ...                                                 ...           ...
# 7422  Charlotte Gainsbourg|Stellan Skarsgård|Stacy M...           3.2
# 7423    Zabou Breitman|Adèle Exarchopoulos|Tchéky Karyo           2.3
# 7424   Jennifer Lawrence|Josh Hutcherson|Liam Hemsworth           3.4
# 7425         Leonardo DiCaprio|Jonah Hill|Margot Robbie           4.0
# 7426       Joaquin Phoenix|Scarlett Johansson|Amy Adams           3.9
#
#             date
# 0     2016-05-12
# 1     2015-01-21
# 2     2013-04-10
# 3     2017-09-20
# 4     2015-04-22
# ...          ...
# 7422  2014-01-01
# 7423  2013-02-13
# 7424  2012-03-21
# 7425  2013-12-25
# 7426  2014-03-19
#
# [7427 rows x 3 columns]
